# %% [markdown]
# # Feature Extraction Methods Retrieval Performance Analysis

# %% [markdown]
# ## Confusion Matrix in Day and Night

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score

RESULTS_DIR = Path('results')

ALGORITHMS = {
    'ORB':        RESULTS_DIR / 'match_details_ref_1_top_1.csv',
    'SIFT':       RESULTS_DIR / 'match_details_SIFT__ref_1_top_1.csv',
    'SUPERPOINT': RESULTS_DIR / 'match_details_SUPERPOINT__ref_1_top_1.csv',
    'NetVLAD':    RESULTS_DIR / 'match_details_NetVLAD__ref_1_top_1.csv',
}

ACTUAL_COL = 'true_place'
PRED_COL   = 'predicted_place'
LIGHT_COL  = 'light'

SPLITS = ('all', 'day', 'night')


def split_by_light(df: pd.DataFrame) -> dict:
    light = df[LIGHT_COL].astype(str)
    return {
        'all':   df,
        'day':   df[light.str.contains('day',   case=False, na=False)],
        'night': df[light.str.contains('night', case=False, na=False)],
    }


def highlight_night_labels(ax, all_labels, night_labels):
    """Color the tick labels red+bold for places that have night queries."""
    night_set = set(night_labels)
    for i, lbl in enumerate(all_labels):
        if lbl in night_set:
            ax.get_xticklabels()[i].set_color('red')
            ax.get_xticklabels()[i].set_fontweight('bold')
            ax.get_yticklabels()[i].set_color('red')
            ax.get_yticklabels()[i].set_fontweight('bold')


# Raw CSVs, no label refinement.
dfs_raw = {algo: pd.read_csv(path) for algo, path in ALGORITHMS.items()}

# Common label set across all algorithms so subplots are aligned.
all_labels = sorted(set().union(*[set(df[ACTUAL_COL]) | set(df[PRED_COL]) for df in dfs_raw.values()]))

# Place ids that have at least one night query (used to highlight tick labels in the night figure).
night_true_labels = set().union(*[set(split_by_light(df)['night'][ACTUAL_COL].unique()) for df in dfs_raw.values()])

for split in SPLITS:
    fig, axes = plt.subplots(
        nrows=1,
        ncols=len(dfs_raw),
        figsize=(5 * len(dfs_raw), 5),
        squeeze=False,
    )
    fig.suptitle(f'Confusion matrices \u2014 {split} (raw labels)', fontsize=14, y=1.02)
    for col, (algo, df) in enumerate(dfs_raw.items()):
        sub = split_by_light(df)[split]
        ax = axes[0, col]
        if sub.empty:
            ax.set_axis_off()
            ax.set_title(f'{algo} (empty)')
            continue
        cm = confusion_matrix(sub[ACTUAL_COL], sub[PRED_COL], labels=all_labels)
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=all_labels)
        disp.plot(cmap='Blues', ax=ax, colorbar=False, values_format='d')
        acc = accuracy_score(sub[ACTUAL_COL], sub[PRED_COL])
        ax.set_title(f'{algo}\nacc = {acc:.4f}, n = {len(sub)}')
        ax.tick_params(axis='x', labelrotation=90, labelsize=6)
        ax.tick_params(axis='y', labelsize=6)
        if split == 'night':
            highlight_night_labels(ax, all_labels, night_true_labels)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Accuracy in Day and Night

# %%
# Per-algorithm, per-split accuracy table (raw labels).
rows = []
for algo, df in dfs_raw.items():
    splits = split_by_light(df)
    rows.append({
        'algorithm': algo,
        **{s: accuracy_score(splits[s][ACTUAL_COL], splits[s][PRED_COL]) if len(splits[s]) else float('nan') for s in SPLITS},
        **{f'n_{s}': len(splits[s]) for s in SPLITS},
    })

acc_df_raw = pd.DataFrame(rows).set_index('algorithm')
display(acc_df_raw.style.format({s: '{:.4f}' for s in SPLITS}))
# Out:
# <style type="text/css">
# </style>
# <table id="T_51d07">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51d07_level0_col0" class="col_heading level0 col0" >all</th>
#       <th id="T_51d07_level0_col1" class="col_heading level0 col1" >day</th>
#       <th id="T_51d07_level0_col2" class="col_heading level0 col2" >night</th>
#       <th id="T_51d07_level0_col3" class="col_heading level0 col3" >n_all</th>
#       <th id="T_51d07_level0_col4" class="col_heading level0 col4" >n_day</th>
#       <th id="T_51d07_level0_col5" class="col_heading level0 col5" >n_night</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >algorithm</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51d07_level0_row0" class="row_heading level0 row0" >ORB</th>
#       <td id="T_51d07_row0_col0" class="data row0 col0" >0.5752</td>
#       <td id="T_51d07_row0_col1" class="data row0 col1" >0.7895</td>
#       <td id="T_51d07_row0_col2" class="data row0 col2" >0.2880</td>
#       <td id="T_51d07_row0_col3" class="data row0 col3" >306</td>
#       <td id="T_51d07_row0_col4" class="data row0 col4" >171</td>
#       <td id="T_51d07_row0_col5" class="data row0 col5" >125</td>
#     </tr>
#     <tr>
#       <th id="T_51d07_level0_row1" class="row_heading level0 row1" >SIFT</th>
#       <td id="T_51d07_row1_col0" class="data row1 col0" >0.7451</td>
#       <td id="T_51d07_row1_col1" class="data row1 col1" >0.8655</td>
#       <td id="T_51d07_row1_col2" class="data row1 col2" >0.5680</td>
#       <td id="T_51d07_row1_col3" class="data row1 col3" >306</td>
#       <td id="T_51d07_row1_col4" class="data row1 col4" >171</td>
#       <td id="T_51d07_row1_col5" class="data row1 col5" >125</td>
#     </tr>
#     <tr>
#       <th id="T_51d07_level0_row2" class="row_heading level0 row2" >SUPERPOINT</th>
#       <td id="T_51d07_row2_col0" class="data row2 col0" >0.8922</td>
#       <td id="T_51d07_row2_col1" class="data row2 col1" >0.9474</td>
#       <td id="T_51d07_row2_col2" class="data row2 col2" >0.8560</td>
#       <td id="T_51d07_row2_col3" class="data row2 col3" >306</td>
#       <td id="T_51d07_row2_col4" class="data row2 col4" >171</td>
#       <td id="T_51d07_row2_col5" class="data row2 col5" >125</td>
#     </tr>
#     <tr>
#       <th id="T_51d07_level0_row3" class="row_heading level0 row3" >NetVLAD</th>
#       <td id="T_51d07_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_51d07_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_51d07_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_51d07_row3_col3" class="data row3 col3" >306</td>
#       <td id="T_51d07_row3_col4" class="data row3 col4" >171</td>
#       <td id="T_51d07_row3_col5" class="data row3 col5" >125</td>
#     </tr>
#   </tbody>
# </table>

# %%
ax = acc_df_raw[list(SPLITS)].plot.bar(figsize=(9, 5), edgecolor='black')
ax.set_ylabel('Accuracy (after label refinement)')
ax.set_ylim(0, 1.05)
ax.set_title('Accuracy by algorithm and lighting condition')
ax.legend(title='condition')
ax.grid(axis='y', linestyle='--', alpha=0.3)
for container in ax.containers:
    ax.bar_label(container, fmt='%.3f', padding=2, fontsize=8)
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Refined Label (Only for provided dataset)

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score

RESULTS_DIR = Path('results')

# Algorithms to compare and their match_details CSV paths.
ALGORITHMS = {
    'ORB':        RESULTS_DIR / 'match_details_ref_1_top_1.csv',
    'SIFT':       RESULTS_DIR / 'match_details_SIFT__ref_1_top_1.csv',
    'SUPERPOINT': RESULTS_DIR / 'match_details_SUPERPOINT__ref_1_top_1.csv',
    'NetVLAD':    RESULTS_DIR / 'match_details_NetVLAD__ref_1_top_1.csv',
}

# 19-20, and 21-22 are the same place with different directinons 
# the camera faces roted 90 degrees, so it was considered as different place
# because the content overlap is less than 50%,
# however, powerful algorithms can match them correctly,
# so a refined label is provided for fair evaluation.
LABEL_ALIASES = {20: 19, 22: 21}

ACTUAL_COL = 'true_place'
PRED_COL   = 'predicted_place'
LIGHT_COL  = 'light'


def canonicalize(series: pd.Series) -> pd.Series:
    return series.map(lambda p: LABEL_ALIASES.get(p, p))


def load_refined(path: Path) -> pd.DataFrame:
    df = pd.read_csv(path)
    df[ACTUAL_COL] = canonicalize(df[ACTUAL_COL])
    df[PRED_COL]   = canonicalize(df[PRED_COL])
    df['correct'] = df[ACTUAL_COL] == df[PRED_COL]
    return df


def split_by_light(df: pd.DataFrame) -> dict:
    light = df[LIGHT_COL].astype(str)
    return {
        'all':   df,
        'day':   df[light.str.contains('day',   case=False, na=False)],
        'night': df[light.str.contains('night', case=False, na=False)],
    }


dfs = {algo: load_refined(p) for algo, p in ALGORITHMS.items()}

print("=== Refined Labels ===")
# list refined correct counts
for algo, df in dfs.items():
    print(f'{algo:>10}: {len(df):4d} rows, {int(df["correct"].sum()):4d} correct after refinement')

print("\n=== Previous Labels ===")
# list previous correct counts
for algo, df in dfs_raw.items():
    print(f'{algo:>10}: {len(df):4d} rows, {int(df["correct"].sum()):4d} correct after refinement')
# Out:
# === Refined Labels ===
#        ORB:  306 rows,  176 correct after refinement
#       SIFT:  306 rows,  232 correct after refinement
# SUPERPOINT:  306 rows,  284 correct after refinement
#    NetVLAD:  306 rows,  306 correct after refinement
#
# === Previous Labels ===
#        ORB:  306 rows,  176 correct after refinement
#       SIFT:  306 rows,  228 correct after refinement
# SUPERPOINT:  306 rows,  273 correct after refinement
#    NetVLAD:  306 rows,  306 correct after refinement

# %%
SPLITS = ('all', 'day', 'night')

# Per-algorithm, per-split accuracy table.
rows = []
for algo, df in dfs.items():
    splits = split_by_light(df)
    rows.append({
        'algorithm': algo,
        **{s: accuracy_score(splits[s][ACTUAL_COL], splits[s][PRED_COL]) if len(splits[s]) else float('nan') for s in SPLITS},
        **{f'n_{s}': len(splits[s]) for s in SPLITS},
    })

acc_df = pd.DataFrame(rows).set_index('algorithm')
display(acc_df.style.format({s: '{:.4f}' for s in SPLITS}))
# Out:
# <style type="text/css">
# </style>
# <table id="T_a965a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a965a_level0_col0" class="col_heading level0 col0" >all</th>
#       <th id="T_a965a_level0_col1" class="col_heading level0 col1" >day</th>
#       <th id="T_a965a_level0_col2" class="col_heading level0 col2" >night</th>
#       <th id="T_a965a_level0_col3" class="col_heading level0 col3" >n_all</th>
#       <th id="T_a965a_level0_col4" class="col_heading level0 col4" >n_day</th>
#       <th id="T_a965a_level0_col5" class="col_heading level0 col5" >n_night</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >algorithm</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a965a_level0_row0" class="row_heading level0 row0" >ORB</th>
#       <td id="T_a965a_row0_col0" class="data row0 col0" >0.5752</td>
#       <td id="T_a965a_row0_col1" class="data row0 col1" >0.7895</td>
#       <td id="T_a965a_row0_col2" class="data row0 col2" >0.2880</td>
#       <td id="T_a965a_row0_col3" class="data row0 col3" >306</td>
#       <td id="T_a965a_row0_col4" class="data row0 col4" >171</td>
#       <td id="T_a965a_row0_col5" class="data row0 col5" >125</td>
#     </tr>
#     <tr>
#       <th id="T_a965a_level0_row1" class="row_heading level0 row1" >SIFT</th>
#       <td id="T_a965a_row1_col0" class="data row1 col0" >0.7582</td>
#       <td id="T_a965a_row1_col1" class="data row1 col1" >0.8713</td>
#       <td id="T_a965a_row1_col2" class="data row1 col2" >0.5920</td>
#       <td id="T_a965a_row1_col3" class="data row1 col3" >306</td>
#       <td id="T_a965a_row1_col4" class="data row1 col4" >171</td>
#       <td id="T_a965a_row1_col5" class="data row1 col5" >125</td>
#     </tr>
#     <tr>
#       <th id="T_a965a_level0_row2" class="row_heading level0 row2" >SUPERPOINT</th>
#       <td id="T_a965a_row2_col0" class="data row2 col0" >0.9281</td>
#       <td id="T_a965a_row2_col1" class="data row2 col1" >0.9532</td>
#       <td id="T_a965a_row2_col2" class="data row2 col2" >0.9360</td>
#       <td id="T_a965a_row2_col3" class="data row2 col3" >306</td>
#       <td id="T_a965a_row2_col4" class="data row2 col4" >171</td>
#       <td id="T_a965a_row2_col5" class="data row2 col5" >125</td>
#     </tr>
#     <tr>
#       <th id="T_a965a_level0_row3" class="row_heading level0 row3" >NetVLAD</th>
#       <td id="T_a965a_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_a965a_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_a965a_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_a965a_row3_col3" class="data row3 col3" >306</td>
#       <td id="T_a965a_row3_col4" class="data row3 col4" >171</td>
#       <td id="T_a965a_row3_col5" class="data row3 col5" >125</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Confusion matrices (refined)

# %%
# One figure per split (all / day / night). Each figure: 1 row, one column per algorithm.
all_labels = sorted(set().union(*[set(df[ACTUAL_COL]) | set(df[PRED_COL]) for df in dfs.values()]))

# Place ids that have at least one night query, in the refined label space.
night_true_labels = set().union(*[set(split_by_light(df)['night'][ACTUAL_COL].unique()) for df in dfs.values()])


def highlight_night_labels(ax, labels, night_labels):
    night_set = set(night_labels)
    for i, lbl in enumerate(labels):
        if lbl in night_set:
            ax.get_xticklabels()[i].set_color('red')
            ax.get_xticklabels()[i].set_fontweight('bold')
            ax.get_yticklabels()[i].set_color('red')
            ax.get_yticklabels()[i].set_fontweight('bold')


for split in SPLITS:
    fig, axes = plt.subplots(
        nrows=1,
        ncols=len(dfs),
        figsize=(5 * len(dfs), 5),
        squeeze=False,
    )
    fig.suptitle(f'Confusion matrices \u2014 {split}', fontsize=14, y=1.02)
    for col, (algo, df) in enumerate(dfs.items()):
        sub = split_by_light(df)[split]
        ax = axes[0, col]
        if sub.empty:
            ax.set_axis_off()
            ax.set_title(f'{algo} (empty)')
            continue
        cm = confusion_matrix(sub[ACTUAL_COL], sub[PRED_COL], labels=all_labels)
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=all_labels)
        disp.plot(cmap='Blues', ax=ax, colorbar=False, values_format='d')
        acc = accuracy_score(sub[ACTUAL_COL], sub[PRED_COL])
        ax.set_title(f'{algo}\nacc = {acc:.4f}, n = {len(sub)}')
        ax.tick_params(axis='x', labelrotation=90, labelsize=6)
        ax.tick_params(axis='y', labelsize=6)
        if split == 'night':
            highlight_night_labels(ax, all_labels, night_true_labels)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Algorithm comparison (refined)

# %%
ax = acc_df[list(SPLITS)].plot.bar(figsize=(9, 5), edgecolor='black')
ax.set_ylabel('Accuracy (after label refinement)')
ax.set_ylim(0, 1.05)
ax.set_title('Accuracy by algorithm and lighting condition')
ax.legend(title='condition')
ax.grid(axis='y', linestyle='--', alpha=0.3)
for container in ax.containers:
    ax.bar_label(container, fmt='%.3f', padding=2, fontsize=8)
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
